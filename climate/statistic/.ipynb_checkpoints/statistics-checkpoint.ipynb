# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv("../data/climate_hangzhou.csv")
data=data.convert_objects(convert_numeric=True)
data.head()
# Out:
#        date  rainfall_morning  rainfall_afternoon  rainfall_night  \
# 0  2012-1-1                 1                 1.5               2
# 1  2012-1-2                 1                 1.0               1
# 2  2012-1-3                 3                 3.0               3
# 3  2012-1-4                 1                 1.0               1
# 4  2012-1-5                 3                 3.5               4
#
#    min_temperature  max_temperature  wind_force
# 0                1                8           3
# 1               10               10           3
# 2                0                7           3
# 3               -1                4           3
# 4                0                5           3

# %%
data.describe()
# Out:
#        rainfall_morning  rainfall_afternoon  rainfall_night  min_temperature  \
# count       1459.000000         1459.000000     1459.000000      1458.000000
# mean           4.666895            4.489719        4.312543        14.087929
# std            4.836852            4.197446        4.483584         8.822161
# min            1.000000            1.000000        1.000000        -4.000000
# 25%            1.000000            1.500000        1.000000         6.000000
# 50%            2.000000            2.500000        2.000000        15.000000
# 75%            7.000000            7.000000        4.000000        22.000000
# max           22.000000           22.000000       22.000000        31.000000
#
#        max_temperature   wind_force
# count      1458.000000  1459.000000
# mean         20.243141     3.207220
# std           9.673161     0.525972
# min          -3.000000     3.000000
# 25%          12.000000     3.000000
# 50%          21.000000     3.000000
# ...

# %%
plt.plot(data["min_temperature"])
plt.plot(data["max_temperature"])
plt.show()

# %%
plt.plot(data["wind_force"])
plt.show()

# %%
plt.plot(data["rainfall_afternoon"])
plt.show()
